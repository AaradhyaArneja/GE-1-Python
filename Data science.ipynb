# %%
#Loading python librabries
import pandas as pd

# %%
#Read any file
df=pd.read_csv(r"C:\Users\hp\Desktop\CS-1\CS1.R.Data Files\datacovid.csv")
df
# Out:
#          dateRep  day  month  year   cases  deaths countriesAndTerritories  \
# 0     11-01-2022   11      1  2022   10441       9                 Austria
# 1     10-01-2022   10      1  2022   10860       2                 Austria
# 2     09-01-2022    9      1  2022    7171       7                 Austria
# 3     08-01-2022    8      1  2022    9028       8                 Austria
# 4     07-01-2022    7      1  2022    8288       7                 Austria
# ...          ...  ...    ...   ...     ...     ...                     ...
# 9175  05-03-2021    5      3  2021    4069      15                  Sweden
# 9176  04-03-2021    4      3  2021    4882      19                  Sweden
# 9177  03-03-2021    3      3  2021    4871      18                  Sweden
# 9178  02-03-2021    2      3  2021    6189      23                  Sweden
# 9179  01-03-2021    1      3  2021  668949   13092                  Sweden
#
#      geoId countryterritoryCode  popData2020 continentExp
# ...

# %%
#Dimesions(rows,colums)
df.shape
# Out:
# (9180, 11)

# %%
#Printing only first  two rows
df.head(2)

#tails function print last rows 
df.tail(5)      #printing last five rows
# Out:
#          dateRep  day  month  year   cases  deaths countriesAndTerritories  \
# 9175  05-03-2021    5      3  2021    4069      15                  Sweden
# 9176  04-03-2021    4      3  2021    4882      19                  Sweden
# 9177  03-03-2021    3      3  2021    4871      18                  Sweden
# 9178  02-03-2021    2      3  2021    6189      23                  Sweden
# 9179  01-03-2021    1      3  2021  668949   13092                  Sweden
#
#      geoId countryterritoryCode  popData2020 continentExp
# 9175    SE                  SWE     10327589       Europe
# 9176    SE                  SWE     10327589       Europe
# 9177    SE                  SWE     10327589       Europe
# 9178    SE                  SWE     10327589       Europe
# 9179    SE                  SWE     10327589       Europe

# %%
df[2:5]   #guves the rows from 2 to 4
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 2  09-01-2022    9      1  2022   7171       7                 Austria    AT
# 3  08-01-2022    8      1  2022   9028       8                 Austria    AT
# 4  07-01-2022    7      1  2022   8288       7                 Austria    AT
#
#   countryterritoryCode  popData2020 continentExp
# 2                  AUT      8901064       Europe
# 3                  AUT      8901064       Europe
# 4                  AUT      8901064       Europe

# %%
#for columns
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2020', 'continentExp'],
#       dtype='object')

# %%
#printing the contenet of a column
df.dateRep
# Out:
# 0       11
# 1       10
# 2        9
# 3        8
# 4        7
#         ..
# 9175     5
# 9176     4
# 9177     3
# 9178     2
# 9179     1
# Name: day, Length: 9180, dtype: int64

# %%
df.day

#another way is :
df['day']    #extracting a property in a dictionery
# Out:
# 0       11
# 1       10
# 2        9
# 3        8
# 4        7
#         ..
# 9175     5
# 9176     4
# 9177     3
# 9178     2
# 9179     1
# Name: day, Length: 9180, dtype: int64

# %%
type(df['day'])   #extracting the type of event
# Out:
# pandas.core.series.Series

# %%
#printing only few columns
df[['day','month','year']]
# Out:
#       day  month  year
# 0      11      1  2022
# 1      10      1  2022
# 2       9      1  2022
# 3       8      1  2022
# 4       7      1  2022
# ...   ...    ...   ...
# 9175    5      3  2021
# 9176    4      3  2021
# 9177    3      3  2021
# 9178    2      3  2021
# 9179    1      3  2021
#
# [9180 rows x 3 columns]

# %%
#Extractibg the max value from the year
df['year'].max()
# Out:
# 2022

# %%
#Extracting the minimun value form the year
df['year'].min()
# Out:
# 2021

# %%
#Calculating the mean from the cases 
df['cases'].mean()
# Out:
# 6913.900762527233

# %%
#Calculating the sd from the cases 
df['cases'].std()
# Out:
# 74868.22462614234

# %%
#Extract the statitics on the columns
df.describe()
# Out:
#                day        month         year         cases        deaths  \
# count  9180.000000  9180.000000  9180.000000  9.180000e+03   9180.000000
# mean     15.215359     7.175381  2021.029412  6.913901e+03     99.478867
# std       8.737915     2.967626     0.168967  7.486822e+04   1844.830847
# min       1.000000     1.000000  2021.000000 -2.001000e+03     -3.000000
# 25%       8.000000     5.000000  2021.000000  1.800000e+02      0.000000
# 50%      15.000000     7.000000  2021.000000  8.660000e+02      6.000000
# 75%      23.000000    10.000000  2021.000000  3.374250e+03     35.000000
# max      31.000000    12.000000  2022.000000  3.645305e+06  97699.000000
#
#         popData2020
# count  9.180000e+03
# mean   1.510301e+07
# std    2.121563e+07
# min    3.874700e+04
# 25%    2.095861e+06
# 50%    6.387122e+06
# 75%    1.152244e+07
# max    8.316671e+07

# %%
#conditional data selection and extraction
df[df.cases>=50000]
# Out:
#          dateRep  day  month  year    cases  deaths countriesAndTerritories  \
# 305   01-03-2021    1      3  2021   456112    8531                 Austria
# 314   03-01-2022    3      1  2022   131388     302                 Belgium
# 611   01-03-2021    1      3  2021   772733   22383                 Belgium
# 917   01-03-2021    1      3  2021   247038   10191                Bulgaria
# 1223  01-03-2021    1      3  2021   242973    5526                 Croatia
# ...          ...  ...    ...   ...      ...     ...                     ...
# 8725  26-07-2021   26      7  2021    61625      47                   Spain
# 8732  19-07-2021   19      7  2021    61628      23                   Spain
# 8873  28-02-2021   28      2  2021  3109689   69142                   Spain
# 8882  03-01-2022    3      1  2022    84612      65                  Sweden
# 9179  01-03-2021    1      3  2021   668949   13092                  Sweden
#
# ...

# %%
#Extract the max value
df[df.cases==df['cases'].max()]
# Out:
#          dateRep  day  month  year    cases  deaths countriesAndTerritories  \
# 3059  01-03-2021    1      3  2021  3645305   86454                  France
#
#      geoId countryterritoryCode  popData2020 continentExp
# 3059    FR                  FRA     67320216       Europe

# %%
#printing the day which has max cases
df['day'][df.cases==df['cases']].max()
# Out:
# 31

# %%
#gives the day along with month and year that has max no. of cases 
df[['day','month','year']][df.cases==df['cases'].max()]
# Out:
#       day  month  year
# 3059    1      3  2021

# %%
df
# Out:
#          dateRep  day  month  year   cases  deaths countriesAndTerritories  \
# 0     11-01-2022   11      1  2022   10441       9                 Austria
# 1     10-01-2022   10      1  2022   10860       2                 Austria
# 2     09-01-2022    9      1  2022    7171       7                 Austria
# 3     08-01-2022    8      1  2022    9028       8                 Austria
# 4     07-01-2022    7      1  2022    8288       7                 Austria
# ...          ...  ...    ...   ...     ...     ...                     ...
# 9175  05-03-2021    5      3  2021    4069      15                  Sweden
# 9176  04-03-2021    4      3  2021    4882      19                  Sweden
# 9177  03-03-2021    3      3  2021    4871      18                  Sweden
# 9178  02-03-2021    2      3  2021    6189      23                  Sweden
# 9179  01-03-2021    1      3  2021  668949   13092                  Sweden
#
#      geoId countryterritoryCode  popData2020 continentExp
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9180, step=1)

# %%
#Changing index
df.set_index('day',inplace=True)

# %%
#extracting location
df.loc[9]
# Out:
#         dateRep  month  year  cases  deaths countriesAndTerritories geoId  \
# day
# 9    09-01-2022      1  2022   7171       7                 Austria    AT
# 9    09-12-2021     12  2021   6208      47                 Austria    AT
# 9    09-11-2021     11  2021   7975      13                 Austria    AT
# 9    09-10-2021     10  2021   1890      16                 Austria    AT
# 9    09-09-2021      9  2021   2505       6                 Austria    AT
# ..          ...    ...   ...    ...     ...                     ...   ...
# 9    09-07-2021      7  2021    228       0                  Sweden    SE
# 9    09-06-2021      6  2021    825       7                  Sweden    SE
# 9    09-05-2021      5  2021   1657      16                  Sweden    SE
# 9    09-04-2021      4  2021   7629      24                  Sweden    SE
# 9    09-03-2021      3  2021   5928      20                  Sweden    SE
#
#     countryterritoryCode  popData2020 continentExp
# day
# ...
